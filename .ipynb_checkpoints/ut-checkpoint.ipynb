# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    roc_auc_score, confusion_matrix, classification_report
)

# Try to use XGBoost; if not available, fallback to RandomForest
use_xgb = True
try:
    from xgboost import XGBClassifier
except Exception:
    use_xgb = False
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("../Downloads/st_export.csv").iloc[:,1:]
for i in range(len(df)):
    df.iloc[i,-3]=df.iloc[i,-3].split("GMT")[0].strip()
df['timestamp'] = pd.to_datetime(df['timestamp'])
a=np.random.randint(len(df))
df.iloc[a:a+5,:]
# Out:
#         klineacc        spread  spreadper         x           vwap  deviation  \
# 45979  195530928  3.421802e+06  21.749876  0.845729  102916.562500   0.003162
# 45980   27044298 -1.329460e+06 -51.771935 -0.801736       8.416674   0.002771
# 45981   32057292 -2.788652e+06 -70.843620 -0.766444       2.403104   0.000581
# 45982  182564880 -7.969589e+04  -0.961192 -0.918177    3433.469727   0.000452
# 45983   23208434 -2.594104e+06 -66.311874 -0.748010     960.969055   0.000136
#
#           ratio      term     sigma         e         h asset  \
# 45979  0.782501  0.536571  0.002085  0.636854  0.562754   BTC
# 45980  1.517719  0.975482  0.019628  0.209044  0.206051   UNI
# 45981  1.708436  0.625376  0.004837  0.128340  0.127640   XRP
# 45982  1.009612  0.616105  0.004692  0.059856  0.059785   ETH
# 45983  1.663119  0.548617  0.002544  0.048865  0.048826   BNB
#
#                 timestamp gap  gaplimit
# 45979 2025-11-12 08:10:14  1m       300
# 45980 2025-11-12 08:10:14  1m       300
# ...

# %%
# -----------------------------
# 1. Copy original DataFrame
# -----------------------------
df_copy = df.copy()

# -----------------------------
# 2. Filter for selected assets
# -----------------------------
selected_assets = ['BTC','ETH','SOL','BNB','DOT','AAVE','BCH','PAXG']
df_copy = df_copy[df_copy['asset'].isin(selected_assets)].copy()

# -----------------------------
# 3. Pivot features by asset
# -----------------------------
feature_cols = ['klineacc','spread','spreadper','x','vwap','deviation','ratio','term','sigma','e','h']
wide_frames = []
for col in feature_cols:
    pivoted = df_copy.pivot_table(index='timestamp', columns='asset', values=col, aggfunc='mean')
    pivoted.columns = [f"{col}__{a}" for a in pivoted.columns]
    wide_frames.append(pivoted)

wide_df = pd.concat(wide_frames, axis=1).sort_index()

# -----------------------------
# 4. Compute BTC return and label into 3 classes
# -----------------------------
btc_vwap = wide_df['vwap__BTC']
wide_df['btc_return'] = btc_vwap.pct_change()

# Widen threshold to ±0.2%
def classify_return(r):
    if r > 0.002:
        return 2  # Up
    elif r < -0.002:
        return 0  # Down
    else:
        return 1  # Neutral

wide_df['target'] = wide_df['btc_return'].shift(-1).apply(classify_return)

# -----------------------------
# 5. Plot BTC return distribution
# -----------------------------
plt.figure(figsize=(8,5))
wide_df['btc_return'].hist(bins=100)
plt.title("BTC Return Distribution")
plt.xlabel("Return")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# -----------------------------
# 6. Balance classes safely
# -----------------------------
model_df = wide_df.dropna()

# Check class counts
counts = model_df['target'].value_counts()
print("Class counts before balancing:\n", counts)

# Option 1: undersample all classes to the smallest size
min_class_size = counts.min()
balanced_df = pd.concat([
    model_df[model_df['target'] == 0].sample(min_class_size, random_state=42),
    model_df[model_df['target'] == 1].sample(min_class_size, random_state=42),
    model_df[model_df['target'] == 2].sample(min_class_size, random_state=42)
])

balanced_df = balanced_df.sort_index()

# -----------------------------
# 7. Create lag features
# -----------------------------
lagged = []
for col in balanced_df.columns:
    if col == 'target':
        continue
    for L in (1,2,3):
        lagged.append(balanced_df[col].shift(L).rename(f"{col}_lag{L}"))

lag_df = pd.concat(lagged, axis=1)
final_df = pd.concat([lag_df, balanced_df[['target']]], axis=1).dropna()
# Out:
# /var/folders/5z/34btjl757md3wk7szryjd3ym0000gn/T/ipykernel_29344/3003637840.py:28: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   wide_df['btc_return'] = btc_vwap.pct_change()
# Class counts before balancing:
#  target
# 0    136
# 2     78
# 1     29
# Name: count, dtype: int64

# %%
# -----------------------------
# 8. Train/test split
# -----------------------------
split_idx = int(len(final_df)*0.8)
X = final_df.drop(columns=['target'])
y = final_df['target']
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

scaler = StandardScaler(with_mean=False)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -----------------------------
# 9. Train XGBoost classifier
# -----------------------------
model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softmax',
    num_class=3,
    tree_method='hist',
    random_state=42
)
model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_class=3, ...)

# %%
# -----------------------------
# 10. Evaluate
# -----------------------------
y_pred = model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification report:")
print(classification_report(y_test, y_pred, digits=4))

cm = confusion_matrix(y_test, y_pred)
print("\nConfusion matrix:\n", cm)

plt.figure(figsize=(6,5))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks([0,1,2], ['Pred Down','Pred Neutral','Pred Up'])
plt.yticks([0,1,2], ['True Down','True Neutral','True Up'])
plt.title("Confusion Matrix (BTC 3-class direction)")
for i in range(3):
    for j in range(3):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='black')
plt.tight_layout()
plt.show()

# -----------------------------
# 11. Feature importance
# -----------------------------
importances = model.feature_importances_
feat_imp = pd.Series(importances, index=X.columns).sort_values(ascending=False)
print("\nTop 25 features by importance:")
print(feat_imp.head(25))

plt.figure(figsize=(10,6))
feat_imp.head(25).plot(kind='bar')
plt.title("Top 25 Feature Importances")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.7058823529411765
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6667    0.5000    0.5714         4
#            1     0.0000    0.0000    0.0000         2
#            2     0.7692    0.9091    0.8333        11
#
#     accuracy                         0.7059        17
#    macro avg     0.4786    0.4697    0.4683        17
# weighted avg     0.6546    0.7059    0.6737        17
#
#
# Confusion matrix:
#  [[ 2  0  2]
#  [ 1  0  1]
#  [ 0  1 10]]
# Top 25 features by importance:
# e__SOL_lag1             0.058836
# h__SOL_lag1             0.054874
# deviation__ETH_lag1     0.028418
# deviation__BTC_lag2     0.018738
# e__ETH_lag3             0.016353
# vwap__BTC_lag2          0.014739
# e__ETH_lag2             0.014240
# klineacc__BCH_lag1      0.013750
# deviation__BCH_lag3     0.013687
# e__BTC_lag1             0.013619
# e__AAVE_lag1            0.013420
# klineacc__PAXG_lag3     0.012337
# ...
