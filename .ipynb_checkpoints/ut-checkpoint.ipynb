# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Downloads/st_export.csv").iloc[:,1:]
for i in range(len(df)):
    df.iloc[i,-3]=df.iloc[i,-3].split("GMT")[0].strip()
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.tail()
# Out:
#          klineacc        spread  spreadper         x          vwap  deviation  \
# 105582  243009088 -1.515287e+06 -19.108099 -0.876498  93193.875000  -0.000261
# 105583   23125126  4.245218e+05   7.591727  0.843956    900.395813  -0.002661
# 105584   42380120  7.252953e+06  31.355587  0.671879    142.525360  -0.005300
# 105585   26964774  1.052250e+05   1.282841  0.886435      2.196158  -0.005946
# 105586   27078804 -5.835642e+05 -22.478600 -0.839400      1.742947  -0.013854
#
#            ratio      term     sigma         e         h asset  \
# 105582  1.191081  0.377895  0.003526 -0.033286 -0.033273   BTC
# 105583  0.924083  0.098463  0.003769 -0.064230 -0.064142   BNB
# 105584  0.686444  0.283867  0.003895 -0.265120 -0.259078   SOL
# 105585  0.987172  0.234254  0.004464 -0.308050 -0.298662   XRP
# 105586  1.224786  0.565329  0.010542 -0.909957 -0.721112   SUI
#
#                  timestamp gap  gaplimit
# 105582 2025-12-03 18:38:29  1m       300
# 105583 2025-12-03 18:38:29  1m       300
# 105584 2025-12-03 18:38:29  1m       300
# 105585 2025-12-03 18:38:29  1m       300
# 105586 2025-12-03 18:38:29  1m       300

# %%
df = df.sort_values('timestamp')

# -----------------------------
# 2. Create lag features
# -----------------------------
df['vwap_lag1'] = df['vwap'].shift(1)
df['spread_lag1'] = df['spread'].shift(1)
df['ratio_lag1'] = df['ratio'].shift(1)
df['sigma_lag1'] = df['sigma'].shift(1)

# %%
# Drop rows with NaN (from lagging)
df = df.dropna()

# -----------------------------
# 3. Define features and target
# -----------------------------
X = df[['vwap_lag1','spread_lag1','ratio_lag1','sigma_lag1','e','h']]
y = df['vwap']   # current VWAP (predicted from previous step)

# -----------------------------
# 4. Train/test split
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# -----------------------------
# 5. Train model
# -----------------------------
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# -----------------------------
# 6. Evaluate
# -----------------------------
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 29
#      26 y_pred = model.predict(X_test)
#      28 mse = mean_squared_error(y_test, y_pred)
# ---> 29 rmse = np.sqrt(mse)
#      31 print("R^2:", r2_score(y_test, y_pred))
#      32 print("RMSE:", rmse)
#
# NameError: name 'np' is not defined

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("R^2:", r2_score(y_test, y_pred))
print("RMSE:", rmse)

# Feature importance
importances = model.feature_importances_
for feat, imp in zip(X.columns, importances):
    print(f"{feat}: {imp:.4f}")
# Out:
# R^2: -0.04276357921064422
# RMSE: 30468.651624546146
# vwap_lag1: 0.2462
# spread_lag1: 0.1591
# ratio_lag1: 0.1594
# sigma_lag1: 0.2047
# e: 0.1156
# h: 0.1150

# %% [markdown]
# # new

# %%
df['return'] = df['vwap'].pct_change()

# Lag features for VWAP and other columns
for col in ['vwap','spread','ratio','sigma','e','h']:
    df[f'{col}_lag1'] = df[col].shift(1)
    df[f'{col}_lag2'] = df[col].shift(2)
    df[f'{col}_lag3'] = df[col].shift(3)

# Target: next-step return
df['target'] = df['return'].shift(-1)

# Drop rows with NaN (from lagging)
df = df.dropna()

# -----------------------------
# 3. Define features and target
# -----------------------------
feature_cols = [c for c in df.columns if 'lag' in c]
X = df[feature_cols]
y = df['target']

# -----------------------------
# 4. Train/test split (time-series style)
# -----------------------------
split_idx = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# -----------------------------
# 5. Train model
# -----------------------------
model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(X_train, y_train)

# -----------------------------
# 6. Evaluate
# -----------------------------
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R^2:", r2)
print("RMSE:", rmse)

# Feature importance
importances = model.feature_importances_
for feat, imp in sorted(zip(feature_cols, importances), key=lambda x: -x[1]):
    print(f"{feat}: {imp:.4f}")
# Out:
# R^2: -0.08376070126411683
# RMSE: 7945.375585005483
# vwap_lag2: 0.0792
# vwap_lag1: 0.0787
# vwap_lag3: 0.0762
# sigma_lag1: 0.0694
# sigma_lag2: 0.0691
# sigma_lag3: 0.0687
# spread_lag3: 0.0684
# spread_lag2: 0.0605
# spread_lag1: 0.0602
# ratio_lag3: 0.0594
# ratio_lag1: 0.0566
# ratio_lag2: 0.0565
# e_lag3: 0.0352
# e_lag1: 0.0343
# h_lag1: 0.0335
# e_lag2: 0.0327
# h_lag3: 0.0314
# h_lag2: 0.0300

# %%
# -----------------------------
# 7. Plot actual vs predicted
# -----------------------------
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label="Actual Returns", alpha=0.7)
plt.plot(y_pred, label="Predicted Returns", alpha=0.7)
plt.legend()
plt.title("Actual vs Predicted VWAP Returns")
plt.show()
