# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    roc_auc_score, confusion_matrix, classification_report, f1_score
)

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
pd.options.display.max_rows = None

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
df = pd.read_csv("../Downloads/st_export.csv").iloc[:,1:]
for i in range(len(df)):
    df.iloc[i,-3]=df.iloc[i,-3].split("GMT")[0].strip()
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
a=np.random.randint(len(df))
df.iloc[a:a+5,:]
# Out:
#         klineacc        spread  spreadper         x          vwap  deviation  \
# 93446  100250536 -5.710986e+06 -48.566540 -0.793446  91256.523438  -0.002732
# 93447   10624884 -1.438284e+05  -3.342660 -0.855477    896.125061  -0.000329
# 93448   33493132  4.428978e+06  20.695633  0.707756    141.103104  -0.009660
# 93449   22113486 -6.474776e+05 -15.281739 -0.826950    489.767273  -0.011306
# 93450   86119240 -2.493419e+06 -35.220108 -0.827435   3016.544922  -0.003502
#
#           ratio      term     sigma         e         h asset  \
# 93446  1.485665  1.187643  0.002019 -2.386726 -0.983239   BTC
# 93447  1.033427  1.525232  0.001660 -0.312593 -0.302795   BNB
# 93448  0.793044  0.738676  0.005845 -0.968237 -0.747928   SOL
# 93449  1.152817  0.932625  0.009952 -1.221469 -0.840087   ZEC
# 93450  1.352201  1.370381  0.004157 -1.561147 -0.915606   ETH
#
#                 timestamp gap  gaplimit
# 93446 2025-11-28 09:41:09  5m        60
# 93447 2025-11-28 09:43:22  3m       100
# 93448 2025-11-28 09:43:22  3m       100
# 93449 2025-11-28 09:43:22  3m       100
# 93450 2025-11-28 09:43:22  3m       100

# %%
ndf = pd.read_csv("../Downloads/st_exportd.csv").iloc[:,1:]
for i in range(len(ndf)):
    ndf.iloc[i,-3]=ndf.iloc[i,-3].split("GMT")[0].strip()
ndf['timestamp'] = pd.to_datetime(ndf['timestamp'])
a=np.random.randint(len(ndf))
ndf.iloc[a:a+5,:]
# Out:
#         klineacc        spread  spreadper         x           vwap  deviation  \
# 34078   26488148 -1.586226e+06 -43.758087 -0.790513     987.358337  -0.008070
# 34079   17821312 -3.278917e+06 -54.422829 -0.705622       2.269628  -0.010190
# 34080   29636880 -4.824612e+05 -22.079174 -0.849464     104.872704  -0.043793
# 34081   41716892  2.517887e+06  48.693920  0.782162       2.958139  -0.024049
# 34082  153388608  2.667445e+06  28.754623  0.845960  101907.125000  -0.003421
#
#           ratio      term     sigma         e         h asset  \
# 34078  1.437581  1.852585  0.003905 -5.504299 -0.999967   BNB
# 34079  1.544228  1.517505  0.004154 -5.748526 -0.999980   XRP
# 34080  1.220792  0.332478  0.019967 -0.890205 -0.711495   LTC
# 34081  0.513061  1.588092  0.021492 -0.911718 -0.721956  NEAR
# 34082  0.712454  1.200135  0.002613 -1.119427 -0.807370   BTC
#
#                 timestamp gap  gaplimit
# 34078 2025-11-09 11:33:25  1m       300
# 34079 2025-11-09 11:33:25  1m       300
# 34080 2025-11-09 11:36:01  3m       100
# 34081 2025-11-09 11:36:01  3m       100
# 34082 2025-11-09 11:36:01  3m       100

# %%
nndf=ndf.iloc[df.tail(1).index.start+1:,:]
len(nndf)
# Out:
# 617

# %%
assets_to_train=[i for i in nndf["asset"].unique().tolist() if i in df["asset"].unique().tolist()]
print(assets_to_train)
# Out:
# ['SOL', 'BTC', 'XRP', 'ZEC', 'ETH', 'BNB', 'BCH', 'SUI', 'ZEN', 'TAO', 'NEAR', 'TON', 'DASH', 'RENDER', 'ORDI', 'WBTC', 'TRUMP', 'AAVE', 'INJ', 'LTC', 'FIL', 'DOT', 'LINK', 'CAKE', 'APT', 'NMR', 'AVAX', 'ETC', 'AR', 'GIGGLE', 'EGLD', 'ICP', 'UNI', 'PAXG']

# %%
c=[[len(df[df["asset"]==i]),i] for i in assets_to_train]

# %%
c = sorted(c, key=lambda x: x[0],reverse=True)
print(c)
# Out:
# [[11362, 'BTC'], [11336, 'ETH'], [10700, 'SOL'], [10692, 'ZEC'], [10346, 'XRP'], [10236, 'BNB'], [5212, 'SUI'], [3726, 'ICP'], [3340, 'DASH'], [3238, 'GIGGLE'], [3089, 'LTC'], [3089, 'LINK'], [2921, 'ZEN'], [2483, 'UNI'], [2437, 'NEAR'], [2379, 'TAO'], [2180, 'FIL'], [1952, 'TRUMP'], [1804, 'AVAX'], [1400, 'PAXG'], [1246, 'BCH'], [830, 'AAVE'], [692, 'AR'], [601, 'DOT'], [513, 'ETC'], [443, 'WBTC'], [393, 'CAKE'], [391, 'RENDER'], [381, 'ORDI'], [360, 'INJ'], [345, 'APT'], [322, 'TON'], [217, 'NMR'], [62, 'EGLD']]

# %% [markdown]
# # new
